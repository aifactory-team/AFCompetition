# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.8.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# download dataset
import gdown

url = 'https://drive.google.com/file/d/1HWl3kawJHxmGv1Ck69bvRIxOMz_9ZQ45/view?usp=sharing'
gdown.download(url=url, output='dataset.zip', quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1HWl3kawJHxmGv1Ck69bvRIxOMz_9ZQ45
# To: /content/dataset.zip
# 100%|██████████| 620M/620M [00:11<00:00, 52.4MB/s]
# 'dataset.zip'

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: dataset/
#    creating: dataset/train/
#    creating: dataset/train/y_train/
#   inflating: dataset/train/y_train/1588.npy
#   inflating: dataset/train/y_train/1371.npy
#   inflating: dataset/train/y_train/0459.npy
#   inflating: dataset/train/y_train/1484.npy
#   inflating: dataset/train/y_train/0940.npy
#   inflating: dataset/train/y_train/0827.npy
#   inflating: dataset/train/y_train/1784.npy
#   inflating: dataset/train/y_train/1689.npy
#   inflating: dataset/train/y_train/0101.npy
#   inflating: dataset/train/y_train/1245.npy
#   inflating: dataset/train/y_train/1161.npy
#   inflating: dataset/train/y_train/1552.npy
#   inflating: dataset/train/y_train/1726.npy
#   inflating: dataset/train/y_train/1018.npy
#   inflating: dataset/train/y_train/0544.npy
#   inflating: dataset/train/y_train/1913.npy
#   inflating: dataset/train/y_train/0038.npy
#   inflating: dataset/train/y_train/1626.npy
#   inflating: dataset/train/y_train/1374.npy
#   inflating: dataset/train/y_train/0854.npy
#   inflating: dataset/train/y_train/0626.npy
#   inflating: dataset/train/y_train/1202.npy
#   inflating: dataset/train/y_train/0780.npy
#   inflating: dataset/train/y_train/0625.npy
#   inflating: dataset/train/y_train/1583.npy
#   inflating: dataset/train/y_train/0921.npy
#   inflating: dataset/train/y_train/0392.npy
#   inflating: dataset/train/y_train/0775.npy
#   inflating: dataset/train/y_train/1531.npy
#   inflating: dataset/train/y_train/0260.npy
#   inflating: dataset/train/y_train/0019.npy
#   inflating: dataset/train/y_train/1164.npy
#   inflating: dataset/train/y_train/1345.npy
#   inflating: dataset/train/y_train/1933.npy
#   inflating: dataset/train/y_train/1894.npy
#   inflating: dataset/train/y_train/0292.npy
#   inflating: dataset/train/y_train/1359.npy
#   inflating: dataset/train/y_train/1034.npy
#   inflating: dataset/train/y_train/1562.npy
#   inflating: dataset/train/y_train/1180.npy
#   inflating: dataset/train/y_train/0768.npy
#   inflating: dataset/train/y_train/1149.npy
#   inflating: dataset/train/y_train/0963.npy
#   inflating: dataset/train/y_train/1695.npy
#   inflating: dataset/train/y_train/0113.npy
#   inflating: dataset/train/y_train/1021.npy
#   inflating: dataset/train/y_train/1546.npy
#   inflating: dataset/train/y_train/0525.npy
#   inflating: dataset/train/y_train/1991.npy
#   inflating: dataset/train/y_train/1290.npy
#   inflating: dataset/train/y_train/1124.npy
#   inflating: dataset/train/y_train/0336.npy
#   inflating: dataset/train/y_train/0808.npy
#   inflating: dataset/train/y_train/0254.npy
#   inflating: dataset/train/y_train/1083.npy
#   inflating: dataset/train/y_train/1152.npy
#   inflating: dataset/train/y_train/0673.npy
#   inflating: dataset/train/y_train/1392.npy
#   inflating: dataset/train/y_train/0471.npy
#   inflating: dataset/train/y_train/0337.npy
#   inflating: dataset/train/y_train/1265.npy
#   inflating: dataset/train/X_train/0894.npy
#   inflating: dataset/train/X_train/0701.npy
#   inflating: dataset/train/X_train/1388.npy
#   inflating: dataset/train/X_train/0120.npy
#   inflating: dataset/train/X_train/0761.npy
#   inflating: dataset/train/X_train/1694.npy
#   inflating: dataset/train/X_train/0428.npy
#   inflating: dataset/train/X_train/2000.npy
#   inflating: dataset/train/X_train/1998.npy
#   inflating: dataset/train/X_train/0543.npy
#   inflating: dataset/train/X_train/0698.npy
#   inflating: dataset/train/X_train/0352.npy
#   inflating: dataset/train/X_train/0023.npy
#   inflating: dataset/train/X_train/1186.npy
#   inflating: dataset/train/X_train/1716.npy
#   inflating: dataset/train/X_train/1171.npy
#   inflating: dataset/train/X_train/1585.npy
#   inflating: dataset/train/X_train/1893.npy
#   inflating: dataset/train/X_train/1474.npy
#   inflating: dataset/train/X_train/0682.npy
#   inflating: dataset/train/X_train/0895.npy
#   inflating: dataset/train/X_train/0993.npy
#   inflating: dataset/train/X_train/1907.npy
#   inflating: dataset/train/X_train/1390.npy
#   inflating: dataset/train/X_train/0058.npy
#   inflating: dataset/train/X_train/0276.npy
#   inflating: dataset/train/X_train/0496.npy
#   inflating: dataset/train/X_train/0739.npy
#   inflating: dataset/train/X_train/0955.npy
#   inflating: dataset/train/X_train/0891.npy
#   inflating: dataset/train/X_train/0729.npy
#   inflating: dataset/train/X_train/1408.npy
#   inflating: dataset/train/X_train/1538.npy
#   inflating: dataset/train/X_train/0161.npy
#   inflating: dataset/train/X_train/0642.npy
#   inflating: dataset/train/X_train/1809.npy
#   inflating: dataset/train/X_train/0875.npy
#   inflating: dataset/train/X_train/0805.npy
#   inflating: dataset/train/X_train/0344.npy
#   inflating: dataset/train/X_train/0978.npy
#   inflating: dataset/train/X_train/1579.npy
#   inflating: dataset/train/X_train/1902.npy
#    creating: dataset/test/
#    creating: dataset/test/X_test/
#   inflating: dataset/test/X_test/0236.npy
#   inflating: dataset/test/X_test/0847.npy
#   inflating: dataset/test/X_test/0031.npy
#   inflating: dataset/test/X_test/0388.npy
#   inflating: dataset/test/X_test/1618.npy
#   inflating: dataset/test/X_test/1517.npy
#   inflating: dataset/test/X_test/0762.npy
#   inflating: dataset/test/X_test/0936.npy
#   inflating: dataset/test/X_test/1437.npy
#   inflating: dataset/test/X_test/1257.npy
#   inflating: dataset/test/X_test/0091.npy
#   inflating: dataset/test/X_test/0771.npy
#   inflating: dataset/test/X_test/0011.npy
#   inflating: dataset/test/X_test/1712.npy
#   inflating: dataset/test/X_test/1636.npy
#   inflating: dataset/test/X_test/0171.npy
#   inflating: dataset/test/X_test/1313.npy
#   inflating: dataset/test/X_test/1304.npy
#   inflating: dataset/test/X_test/0001.npy
#   inflating: dataset/test/X_test/1172.npy
#   inflating: dataset/test/X_test/1658.npy
#   inflating: dataset/test/X_test/1354.npy
#   inflating: dataset/test/X_test/1827.npy
#   inflating: dataset/test/X_test/0500.npy
#   inflating: dataset/test/X_test/1194.npy
#   inflating: dataset/test/X_test/1494.npy
#   inflating: dataset/test/X_test/1183.npy
#   inflating: dataset/test/X_test/0813.npy
#   inflating: dataset/test/X_test/1485.npy
#   inflating: dataset/test/X_test/0395.npy
#   inflating: dataset/test/X_test/1293.npy
#   inflating: dataset/test/X_test/1317.npy
#   inflating: dataset/test/X_test/0217.npy
#   inflating: dataset/test/X_test/1320.npy
#   inflating: dataset/test/X_test/1301.npy
#   inflating: dataset/test/X_test/1842.npy
#   inflating: dataset/test/X_test/0085.npy
#   inflating: dataset/test/X_test/1049.npy
#   inflating: dataset/test/X_test/0646.npy
#   inflating: dataset/test/X_test/1278.npy
#   inflating: dataset/test/X_test/0645.npy
#   inflating: dataset/test/X_test/0305.npy
#   inflating: dataset/test/X_test/1389.npy
#   inflating: dataset/test/X_test/0539.npy
#   inflating: dataset/test/X_test/0202.npy
#   inflating: dataset/test/X_test/0710.npy
#   inflating: dataset/test/X_test/0951.npy
#   inflating: dataset/test/X_test/1918.npy
#   inflating: dataset/test/X_test/0321.npy
#   inflating: dataset/test/X_test/1112.npy
#   inflating: dataset/test/X_test/0873.npy
#   inflating: dataset/test/X_test/1979.npy
#   inflating: dataset/test/X_test/0937.npy
#   inflating: dataset/test/X_test/1705.npy
#   inflating: dataset/test/X_test/1576.npy
#   inflating: dataset/test/X_test/0815.npy
#   inflating: dataset/test/X_test/0495.npy
#   inflating: dataset/test/X_test/0656.npy
#   inflating: dataset/test/X_test/1756.npy
#   inflating: dataset/test/X_test/0683.npy
#   inflating: dataset/test/X_test/1151.npy
#   inflating: dataset/test/X_test/0303.npy
#   inflating: dataset/test/X_test/0602.npy
#   inflating: dataset/test/X_test/0294.npy
#   inflating: dataset/test/X_test/1897.npy
#   inflating: dataset/test/X_test/0485.npy
#   inflating: dataset/test/X_test/0508.npy
#   inflating: dataset/test/X_test/0466.npy
#   inflating: dataset/test/X_test/1732.npy
#   inflating: dataset/test/X_test/1802.npy
#   inflating: dataset/test/X_test/0273.npy
#   inflating: dataset/test/X_test/0791.npy
#   inflating: dataset/test/X_test/1075.npy
#   inflating: dataset/test/X_test/0456.npy
#   inflating: dataset/test/X_test/0306.npy
#   inflating: dataset/test/X_test/0497.npy
#   inflating: dataset/test/X_test/1130.npy
#   inflating: dataset/test/X_test/0983.npy
#   inflating: dataset/test/X_test/0453.npy
#   inflating: dataset/test/X_test/0201.npy
#   inflating: dataset/test/X_test/0372.npy
#   inflating: dataset/test/X_test/0299.npy
#   inflating: dataset/test/X_test/0443.npy
#   inflating: dataset/test/X_test/1468.npy
#   inflating: dataset/test/X_test/1623.npy
#   inflating: dataset/test/X_test/1426.npy
#   inflating: dataset/test/X_test/1896.npy
#   inflating: dataset/test/X_test/0421.npy
#   inflating: dataset/test/X_test/1749.npy
#   inflating: dataset/test/X_test/1145.npy
#   inflating: dataset/test/X_test/0315.npy
#   inflating: dataset/test/X_test/0994.npy
#   inflating: dataset/test/X_test/1940.npy
#   inflating: dataset/test/X_test/0918.npy
#   inflating: dataset/test/X_test/0488.npy
#   inflating: dataset/test/X_test/1411.npy
#   inflating: dataset/test/X_test/1195.npy
#   inflating: dataset/test/X_test/0498.npy
#   inflating: dataset/test/X_test/1275.npy
#   inflating: dataset/test/X_test/0255.npy
#    creating: dataset/test/y_test/
#   inflating: dataset/test/y_test/0236.npy
#   inflating: dataset/test/y_test/0847.npy
#   inflating: dataset/test/y_test/0031.npy
#   inflating: dataset/test/y_test/0388.npy
#   inflating: dataset/test/y_test/1618.npy
#   inflating: dataset/test/y_test/1517.npy
#   inflating: dataset/test/y_test/0762.npy
#   inflating: dataset/test/y_test/0936.npy
#   inflating: dataset/test/y_test/1437.npy
#   inflating: dataset/test/y_test/1257.npy
#   inflating: dataset/test/y_test/0091.npy
#   inflating: dataset/test/y_test/0771.npy
#   inflating: dataset/test/y_test/0011.npy
#   inflating: dataset/test/y_test/1712.npy
#   inflating: dataset/test/y_test/1636.npy
#   inflating: dataset/test/y_test/0171.npy
#   inflating: dataset/test/y_test/1313.npy
#   inflating: dataset/test/y_test/1304.npy
#   inflating: dataset/test/y_test/0001.npy
#   inflating: dataset/test/y_test/1172.npy
#   inflating: dataset/test/y_test/1658.npy
#   inflating: dataset/test/y_test/1354.npy
#   inflating: dataset/test/y_test/1827.npy
#   inflating: dataset/test/y_test/0500.npy
#   inflating: dataset/test/y_test/1194.npy
#   inflating: dataset/test/y_test/1494.npy
#   inflating: dataset/test/y_test/1183.npy
#   inflating: dataset/test/y_test/0813.npy
#   inflating: dataset/test/y_test/1485.npy
#   inflating: dataset/test/y_test/0395.npy
#   inflating: dataset/test/y_test/1293.npy
#   inflating: dataset/test/y_test/1317.npy
#   inflating: dataset/test/y_test/0217.npy
#   inflating: dataset/test/y_test/1320.npy
#   inflating: dataset/test/y_test/1301.npy
#   inflating: dataset/test/y_test/1842.npy
#   inflating: dataset/test/y_test/0085.npy
#   inflating: dataset/test/y_test/1049.npy
#   inflating: dataset/test/y_test/0646.npy
#   inflating: dataset/test/y_test/1278.npy
#   inflating: dataset/test/y_test/0645.npy
#   inflating: dataset/test/y_test/0305.npy
#   inflating: dataset/test/y_test/1389.npy
#   inflating: dataset/test/y_test/0539.npy
#   inflating: dataset/test/y_test/0202.npy
#   inflating: dataset/test/y_test/0710.npy
#   inflating: dataset/test/y_test/0951.npy
#   inflating: dataset/test/y_test/1918.npy
#   inflating: dataset/test/y_test/0321.npy
#   inflating: dataset/test/y_test/1112.npy
#   inflating: dataset/test/y_test/0873.npy
#   inflating: dataset/test/y_test/1979.npy
#   inflating: dataset/test/y_test/0937.npy
#   inflating: dataset/test/y_test/1705.npy
#   inflating: dataset/test/y_test/1576.npy
#   inflating: dataset/test/y_test/0815.npy
#   inflating: dataset/test/y_test/0495.npy
#   inflating: dataset/test/y_test/0656.npy
#   inflating: dataset/test/y_test/1756.npy
#   inflating: dataset/test/y_test/0683.npy
#   inflating: dataset/test/y_test/1151.npy
#   inflating: dataset/test/y_test/0303.npy
#   inflating: dataset/test/y_test/0602.npy
#   inflating: dataset/test/y_test/0294.npy
#   inflating: dataset/test/y_test/1897.npy
#   inflating: dataset/test/y_test/0485.npy
#   inflating: dataset/test/y_test/0508.npy
#   inflating: dataset/test/y_test/0466.npy
#   inflating: dataset/test/y_test/1732.npy
#   inflating: dataset/test/y_test/1802.npy
#   inflating: dataset/test/y_test/0273.npy
#   inflating: dataset/test/y_test/0791.npy
#   inflating: dataset/test/y_test/1075.npy
#   inflating: dataset/test/y_test/0456.npy
#   inflating: dataset/test/y_test/0306.npy
#   inflating: dataset/test/y_test/0497.npy
#   inflating: dataset/test/y_test/1130.npy
#   inflating: dataset/test/y_test/0983.npy
#   inflating: dataset/test/y_test/0453.npy
#   inflating: dataset/test/y_test/0201.npy
#   inflating: dataset/test/y_test/0372.npy
#   inflating: dataset/test/y_test/0299.npy
#   inflating: dataset/test/y_test/0443.npy
#   inflating: dataset/test/y_test/1468.npy
#   inflating: dataset/test/y_test/1623.npy
#   inflating: dataset/test/y_test/1426.npy
#   inflating: dataset/test/y_test/1896.npy
#   inflating: dataset/test/y_test/0421.npy
#   inflating: dataset/test/y_test/1749.npy
#   inflating: dataset/test/y_test/1145.npy
#   inflating: dataset/test/y_test/0315.npy
#   inflating: dataset/test/y_test/0994.npy
#   inflating: dataset/test/y_test/1940.npy
#   inflating: dataset/test/y_test/0918.npy
#   inflating: dataset/test/y_test/0488.npy
#   inflating: dataset/test/y_test/1411.npy
#   inflating: dataset/test/y_test/1195.npy
#   inflating: dataset/test/y_test/0498.npy
#   inflating: dataset/test/y_test/1275.npy
#   inflating: dataset/test/y_test/0255.npy

# %%
import glob                                                                                                                     # 파일 목록을 보여주기 위한 라이브러리
from tqdm import tqdm                                                                                                     # 반복수행에서 진행 단계를 보여주기 위한 라이브러리
import shutil                                                                                                                    # 파일 복사, 이동 등의 명령을 위한 라이브러리
from PIL import Image                                                                                                       # 이미지 파일 처리 라이브러리
import numpy as np                                                                                                          # 수치연산 라이브러리
import tensorflow as tf                                                                                                       # 텐서플로우 딥러닝 프레임워크 
import random                                                                                                                 # 난수 생성 라이브러리
import matplotlib.pyplot as plt                                                                                             # 시각화 라이브러리
from tqdm import tqdm

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization, Add, Dropout, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

SEED = 123                                                                                                                      # 이하 무작위로 결정되는 요소들의 난수를 고정하여 재현 가능하게 설정
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Get data

# train path
x_train_paths = glob.glob('./dataset/train/X_train/*.npy')[:300]
y_train_paths = [x.replace('/X_train', '/y_train') for x in x_train_paths]

# test path
x_test_paths = glob.glob('./dataset/test/X_test/*.npy')[:100]
y_test_paths = [x.replace('/X_test', '/y_test') for x in x_test_paths]

# num data
print('Xy train:', len(x_train_paths), len(y_train_paths))
print('Xy test:', len(x_test_paths), len(y_test_paths))
# Out:
# Xy train: 300 300
# Xy test: 100 100

# %%
def make_data_array(npy_paths):
    data_arr = []
    for npy_path in npy_paths:
        data = np.load(npy_path) # (224, 224, 20)
        data_arr.append(data)
    data_arr = np.array(data_arr, np.float64) # (N, 224, 224, 20)
    return data_arr

X_train = make_data_array(x_train_paths) / 255.
y_train = make_data_array(y_train_paths)
X_test = make_data_array(x_test_paths) / 255.
y_test = make_data_array(y_test_paths)

print('Xy train:', X_train.shape, y_train.shape)
print('Xy test:', X_test.shape, y_test.shape)
# Out:
# Xy train: (300, 224, 224, 20) (300, 224, 224, 5)
# Xy test: (100, 224, 224, 20) (100, 224, 224, 5)

# %%
# Data Visualization
for input_seq in X_train[:3]:
    fig = plt.figure(figsize=(25,5))
    for i in range(20):
        ax = fig.add_subplot(1,20,i+1)
        ax.imshow(input_seq[:, :, i])
        ax.set_axis_off()
        ax.set_title(f'Seq:{i+1}')
    plt.show()
    plt.close('all')

# %%
IMG_SIZE = 224
BATCH_SIZE = 2
IN_LEN = 20
OUT_LEN = 5

# %% [markdown]
# # Model

# %%
# UNet
def UNet(input_shape, output_size):
    # Encoder
    inputs = Input(shape=input_shape)
    enc1 = Conv2D(filters = 64, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(inputs)
    enc1 = Conv2D(filters = 64, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(enc1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(enc1)

    enc2 = Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(pool1)
    enc2 = Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(enc2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(enc2)

    enc3 = Conv2D(filters = 256, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(pool2)
    enc3 = Conv2D(filters = 256, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(enc3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(enc3)

    enc4 = Conv2D(filters = 512, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(pool3)
    enc4 = Conv2D(filters = 512, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(enc4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(enc4)

    # Bridge
    bridge = Conv2D(filters = 512, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(pool4)

    # Decoder
    up4 = Conv2DTranspose(filters = 512, kernel_size = 3, strides = 2, activation = 'relu', padding = 'same')(bridge)
    merge4 = concatenate([enc4, up4], axis = 3)
    dec4 = Conv2D(filters = 512, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(merge4)
    dec4 = Conv2D(filters = 512, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(dec4)

    up3 = Conv2DTranspose(filters = 256, kernel_size = 3, strides = 2, activation = 'relu', padding = 'same')(dec4)
    merge3 = concatenate([enc3, up3], axis = 3)
    dec3 = Conv2D(filters = 256, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(merge3)
    dec3 = Conv2D(filters = 256, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(dec3)

    up2 = Conv2DTranspose(filters = 128, kernel_size = 3, strides = 2, activation = 'relu', padding = 'same')(dec3)
    merge2 = concatenate([enc2, up2], axis = 3)
    dec2 = Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(merge2)
    dec2 = Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(dec2)

    up1 = Conv2DTranspose(filters = 64, kernel_size = 3, strides = 2, activation = 'relu', padding = 'same')(dec2)
    merge1 = concatenate([enc1, up1], axis = 3)
    dec1 = Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(merge1)
    dec1 = Conv2D(filters = 128, kernel_size = 3, activation = 'relu', padding = 'same', kernel_initializer="he_normal")(dec1)

    outputs = Conv2D(filters = output_size, kernel_size = 1, activation = 'linear', padding = 'same')(dec1)

    return Model(inputs = inputs, outputs = outputs)

# %%
tf.keras.backend.clear_session()

# 모델 구축
model = UNet(input_shape = (IMG_SIZE, IMG_SIZE, IN_LEN), output_size=OUT_LEN)
# 모델 컴파일
model.compile(optimizer=Adam(), loss='mae')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 2  0           []
#                                 0)]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  11584       ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 512)  2359808     ['max_pooling2d_3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 512)  2359808    ['conv2d_8[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 1024  0           ['conv2d_7[0][0]',
#                                 )                                 'conv2d_transpose[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 256)  1179904    ['conv2d_10[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_11[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 12  295040     ['conv2d_12[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_3[0][0]',
#                                 6)                                'conv2d_transpose_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 112, 112, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_13[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 64  73792      ['conv2d_14[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_1[0][0]',
#                                 8)                                'conv2d_transpose_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 224, 224, 12  147584      ['concatenate_3[0][0]']
#                                 8)
#
#  conv2d_16 (Conv2D)             (None, 224, 224, 12  147584      ['conv2d_15[0][0]']
#                                 8)
#
#  conv2d_17 (Conv2D)             (None, 224, 224, 5)  645         ['conv2d_16[0][0]']
#
# ==================================================================================================
# Total params: 20,550,853
# Trainable params: 20,550,853
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model in/output test
samples = np.random.rand(1, 224, 224, 20)
pred = model.predict(samples)
print(samples.shape, pred.shape)
# Out:
# 1/1 [==============================] - 9s 9s/step
# (1, 224, 224, 20) (1, 224, 224, 5)

# %%
# download pretrained weights
url = 'https://drive.google.com/file/d/1O4CMzISAOjsdGUQKX1M3R0BPG9app3Ae/view?usp=sharing'
gdown.download(url=url, output='pretrained.h5', quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1O4CMzISAOjsdGUQKX1M3R0BPG9app3Ae
# To: /content/pretrained.h5
# 100%|██████████| 82.3M/82.3M [00:01<00:00, 81.9MB/s]
# 'pretrained.h5'

# %%
# load pretrained weights
model.load_weights('pretrained.h5')

# save best weights
model_checkpoint = ModelCheckpoint(filepath='best.h5',
                                   save_weights_only=True,
                                   monitor='val_loss',
                                   mode='min',
                                   save_best_only=True,
                                   verbose=True)

# training start 
hist = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=BATCH_SIZE,
    validation_split=0.3,
    callbacks=[model_checkpoint]
    )
# Out:
# Epoch 1/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 1: val_loss improved from inf to 0.02661, saving model to best.h5
# 105/105 [==============================] - 20s 150ms/step - loss: 0.0374 - val_loss: 0.0266
# Epoch 2/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0223
# Epoch 2: val_loss improved from 0.02661 to 0.01857, saving model to best.h5
# 105/105 [==============================] - 15s 140ms/step - loss: 0.0223 - val_loss: 0.0186
# Epoch 3/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 3: val_loss did not improve from 0.01857
# 105/105 [==============================] - 15s 140ms/step - loss: 0.0192 - val_loss: 0.0199
# Epoch 4/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 4: val_loss improved from 0.01857 to 0.01595, saving model to best.h5
# 105/105 [==============================] - 16s 148ms/step - loss: 0.0180 - val_loss: 0.0159
# Epoch 5/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0195
# Epoch 5: val_loss improved from 0.01595 to 0.01314, saving model to best.h5
# 105/105 [==============================] - 16s 150ms/step - loss: 0.0195 - val_loss: 0.0131
# Epoch 6/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 6: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 150ms/step - loss: 0.0162 - val_loss: 0.0152
# Epoch 7/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 7: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 151ms/step - loss: 0.0171 - val_loss: 0.0179
# Epoch 8/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0174
# Epoch 8: val_loss did not improve from 0.01314
# 105/105 [==============================] - 15s 146ms/step - loss: 0.0174 - val_loss: 0.0153
# Epoch 9/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 9: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 152ms/step - loss: 0.0157 - val_loss: 0.0162
# Epoch 10/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 10: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 154ms/step - loss: 0.0186 - val_loss: 0.0240
# Epoch 11/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 11: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 150ms/step - loss: 0.0153 - val_loss: 0.0141
# Epoch 12/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 12: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0158 - val_loss: 0.0217
# Epoch 13/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 13: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 152ms/step - loss: 0.0164 - val_loss: 0.0135
# Epoch 14/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 14: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 148ms/step - loss: 0.0135 - val_loss: 0.0164
# Epoch 15/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 15: val_loss did not improve from 0.01314
# 105/105 [==============================] - 16s 148ms/step - loss: 0.0159 - val_loss: 0.0145
# Epoch 16/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 16: val_loss improved from 0.01314 to 0.01273, saving model to best.h5
# 105/105 [==============================] - 16s 151ms/step - loss: 0.0156 - val_loss: 0.0127
# Epoch 17/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 17: val_loss did not improve from 0.01273
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0130 - val_loss: 0.0152
# Epoch 18/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0149
# Epoch 18: val_loss did not improve from 0.01273
# 105/105 [==============================] - 16s 152ms/step - loss: 0.0149 - val_loss: 0.0163
# Epoch 19/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 19: val_loss did not improve from 0.01273
# 105/105 [==============================] - 15s 148ms/step - loss: 0.0126 - val_loss: 0.0130
# Epoch 20/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 20: val_loss did not improve from 0.01273
# 105/105 [==============================] - 15s 148ms/step - loss: 0.0141 - val_loss: 0.0128
# Epoch 21/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 21: val_loss did not improve from 0.01273
# 105/105 [==============================] - 16s 148ms/step - loss: 0.0120 - val_loss: 0.0137
# Epoch 22/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 22: val_loss did not improve from 0.01273
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0120 - val_loss: 0.0136
# Epoch 23/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 23: val_loss improved from 0.01273 to 0.01084, saving model to best.h5
# 105/105 [==============================] - 16s 150ms/step - loss: 0.0117 - val_loss: 0.0108
# Epoch 24/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 24: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 152ms/step - loss: 0.0118 - val_loss: 0.0122
# Epoch 25/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 25: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 148ms/step - loss: 0.0132 - val_loss: 0.0117
# Epoch 26/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 26: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 148ms/step - loss: 0.0127 - val_loss: 0.0126
# Epoch 27/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 27: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 28/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 28: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0110 - val_loss: 0.0115
# Epoch 29/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 29: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0117 - val_loss: 0.0125
# Epoch 30/30
# 105/105 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 30: val_loss did not improve from 0.01084
# 105/105 [==============================] - 16s 153ms/step - loss: 0.0112 - val_loss: 0.0122

# %%
del X_train
del y_train

# %%
import pandas as pd
hist_df = pd.DataFrame(data=hist.history)
plt.figure()
hist_df.plot()
plt.show()

# %%
model.load_weights('best.h5')
mae_score = model.evaluate(X_test, y_test)
print('MAE:', mae_score)
# Out:
# 4/4 [==============================] - 11s 1s/step - loss: 0.0114
# MAE: 0.011441800743341446

# %%
# predict test data
preds = model.predict(X_test)
preds.shape
# Out:
# 4/4 [==============================] - 2s 527ms/step
# (100, 224, 224, 5)

# %%
# Visual pred image
pred_samples = preds[:10]
gt_samples = y_test[:10]
for pred, gt in zip(pred_samples, gt_samples):
    fig = plt.figure(figsize=(20,5))
    for i in range(5):
        ax = fig.add_subplot(2,5,i+1)
        ax.imshow(pred[:, :, i])
        ax.set_title(f'Pred:{i+1}')
        ax.set_axis_off()
    for i in range(5):
        ax = fig.add_subplot(2,5,i+1+5)
        ax.imshow(gt[:, :, i])
        ax.set_title(f'GT:{i+1}')
        ax.set_axis_off()

    plt.show()
    plt.close('all')

# %%
# 제출용 파일 저장
np.save("y_pred.npy", preds)

# %%
from google.colab import files
dfn = 'y_pred.npy'
files.download(dfn)
